# %%
print("hello world")
print("khuhi verma")
# Out:
# hello world
# khuhi verma

# %%
print("today i setup for jupyter")
# Out:
# today i setup for jupyter

# %%
print("for new cell , first step is  -A ,second step  press escap with b ,third step is press + code located at menubar")
# Out:
# for new cell , first step is  -A ,second step  press escap with b ,third step is press + code located at menubar
